# %% [markdown]
# <a href="https://colab.research.google.com/github/dhanya200610/GENAI_TASK/blob/main/Task_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import pipeline

# %%
sentiment_analyzer = pipeline(
    "sentiment-analysis",
    model="distilbert-base-uncased-finetuned-sst-2-english"
)
# Out:
# Device set to use cpu

# %%
sentences = [
    "This project is very useful and impressive",
    "The disaster response system failed badly",
    "I am happy with the results",
    "This is a terrible experience"
]

# %%
results = sentiment_analyzer(sentences)

# %%
for text, result in zip(sentences, results):
    print(f"Text: {text}")
    print(f"Sentiment: {result['label']} | Confidence: {result['score']:.2f}")
    print("-" * 50)
# Out:
# Text: This project is very useful and impressive
# Sentiment: POSITIVE | Confidence: 1.00
# --------------------------------------------------
# Text: The disaster response system failed badly
# Sentiment: NEGATIVE | Confidence: 1.00
# --------------------------------------------------
# Text: I am happy with the results
# Sentiment: POSITIVE | Confidence: 1.00
# --------------------------------------------------
# Text: This is a terrible experience
# Sentiment: NEGATIVE | Confidence: 1.00
# --------------------------------------------------
